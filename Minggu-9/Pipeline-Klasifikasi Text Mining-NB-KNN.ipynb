# %% [markdown]
# ## Klasifikasi Text Mining menggunakan Naive Bayes

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# import sys
# sys.path.append('/content/drive/My Drive/Colab Notebooks/AMS2023')

# %%
# !pip install ekphrasis

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

# %%
import re
import string 
import pandas as pd
from copy import deepcopy

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

# %%
df = pd.read_csv('Dataset_Sentimen_Emosi.csv')

# %%
df.head()
# Out:
#    label                                              tweet
# 0  anger  Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
# 1  anger  Sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2  happy  Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 3  anger  Jln Jatibaru,bagian dari wilayah Tn Abang.Peng...
# 4  happy  Sharing pengalaman aja, kemarin jam 18.00 bata...

# %% [markdown]
# karena kita hanya ingin fokus di Sentimen analysis, maka kita hanya pakai `Sentimen` sebagai target class nya **class**

# %%
df = df.drop(['label'], axis=1)

# %%
df.head()
# Out:
#                                                tweet
# 0  Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
# 1  Sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2  Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 3  Jln Jatibaru,bagian dari wilayah Tn Abang.Peng...
# 4  Sharing pengalaman aja, kemarin jam 18.00 bata...

# %%
def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))

def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space_alzami(text):
    return " ".join(text.split())

def remove_emoji_alzami(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub('\s+',' ',text)

def remove_rt(text):
    return text.replace('RT'," ")

def remove_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

def remove_incomplete_url(text):
    return text.replace("http://", " ").replace("https://", " ")

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def change_stripe(text):
    return text.replace('-'," ")

def lower(text):
    return text.lower()

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text)

# %%
text_processor = TextPreProcessor(
    normalize=['url', 'email', 'user', 'number'],
    annotate={"hashtag", "allcaps", "elongated", "repeated"},
    fix_html=True,
    segmenter="twitter",
    corrector="twitter",
    unpack_hashtags=True,
    unpack_contractions=True,
    spell_correct_elong=False,
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    dicts=[emoticons]
)
# Out:
# e:\STKI\env\Lib\site-packages\ekphrasis\classes\tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...
# e:\STKI\env\Lib\site-packages\ekphrasis\classes\exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in

# %%
final_string = []

for text in df['tweet'].values:
    proc = bersih_data(text)
    proc = remove_rt(proc)
    proc = lower(proc)
    proc = change_stripe(proc)
    proc = remove_tab(proc)
    proc = remove_tab2(proc)
    proc = non_ascii(proc)
    proc = remove_incomplete_url(proc)
    proc = remove_single_char(proc)
    proc = remove_punctuation(proc)
    proc = remove_space_alzami(proc)

    final_string.append(proc)

# %%
df["step01"] = final_string

# %%
df.head(1)
# Out:
#                                                tweet  \
# 0  Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
#
#                                               step01
# 0  soal jln jatibaru polisi tdk bs allcaps gertak...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4401 entries, 0 to 4400
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tweet   4401 non-null   object
#  1   step01  4401 non-null   object
# dtypes: object(2)
# memory usage: 68.9+ KB

# %%
df_hapus = df[~df['step01'].str.contains(" ")]

# %%
df_new = df[~df.isin(df_hapus)].dropna()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4401 entries, 0 to 4400
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tweet   4401 non-null   object
#  1   step01  4401 non-null   object
# dtypes: object(2)
# memory usage: 68.9+ KB

# %%
# token
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df['step01'].apply(word_tokenize_wrapper)

# %%
df_new.head(10)
# Out:
#                                                tweet  \
# 0  Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
# 1  Sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2  Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 3  Jln Jatibaru,bagian dari wilayah Tn Abang.Peng...
# 4  Sharing pengalaman aja, kemarin jam 18.00 bata...
# 5  Dari sekian banyak thread yang aku baca, threa...
# 6  Sharing sama temen tuh emg guna bgt. Disaat lu...
# 7  Orang lain kalau pake ponco itu buat jas hujan...
# 8  Contoh mereka yg gemar menyudutkan, teriak pal...
# 9  Pulang udah H-4 lebaran dilema sekali. Seperti...
#
#                                               step01  \
# 0  soal jln jatibaru polisi tdk bs allcaps gertak...
# 1  sesama cewe lho kayaknya harusnya bisa lebih r...
# 2  kepingin gudeg mbarek bu hj amad foto dari goo...
# 3  jln jatibaru bagian dari wilayah tn abang peng...
# 4  sharing pengalaman aja kemarin jam number bata...
# 5  dari sekian banyak thread yang aku baca thread...
# 6  sharing sama temen tuh emg guna bgt disaat lu ...
# 7  orang lain kalau pake ponco itu buat jas hujan...
# 8  contoh mereka yg gemar menyudutkan teriak pali...
# 9  pulang udah number lebaran dilema sekali seper...
#
#                                               tokens
# 0  [soal, jln, jatibaru, polisi, tdk, bs, allcaps...
# 1  [sesama, cewe, lho, kayaknya, harusnya, bisa, ...
# 2  [kepingin, gudeg, mbarek, bu, hj, amad, foto, ...
# 3  [jln, jatibaru, bagian, dari, wilayah, tn, aba...
# 4  [sharing, pengalaman, aja, kemarin, jam, numbe...
# 5  [dari, sekian, banyak, thread, yang, aku, baca...
# 6  [sharing, sama, temen, tuh, emg, guna, bgt, di...
# 7  [orang, lain, kalau, pake, ponco, itu, buat, j...
# 8  [contoh, mereka, yg, gemar, menyudutkan, teria...
# 9  [pulang, udah, number, lebaran, dilema, sekali...

# %%
import pandas as pd

# Kamus perbaikan kata (alay -> baku)
data = {
    "before": [
        "gk", "ga", "nggak", "tdk",
        "bgt", "bgtt",
        "yg", "dgn", "dr", "utk",
        "krn", "aja", "sm", "dlm", "pd"
    ],
    "after": [
        "tidak", "tidak", "tidak", "tidak",
        "banget", "banget",
        "yang", "dengan", "dari", "untuk",
        "karena", "saja", "sama", "dalam", "pada"
    ]
}

# Buat DataFrame
kamus_df = pd.DataFrame(data)

# Simpan ke Excel
kamus_df.to_excel("kamus_perbaikan_kata.xlsx", index=False)

print("File kamus_perbaikan_kata.xlsx berhasil dibuat")
# Out:
# File kamus_perbaikan_kata.xlsx berhasil dibuat

# %%
normalized_word = pd.read_excel("kamus_perbaikan_kata.xlsx")

normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]

df_new['tokens_perbaikan'] = df_new['tokens'].apply(normalized_term)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_6452\3278828234.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] not in normalized_word_dict:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_6452\3278828234.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   normalized_word_dict[row[0]] = row[1]

# %%
df_new.head()
# Out:
#                                                tweet  \
# 0  Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
# 1  Sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2  Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 3  Jln Jatibaru,bagian dari wilayah Tn Abang.Peng...
# 4  Sharing pengalaman aja, kemarin jam 18.00 bata...
#
#                                               step01  \
# 0  soal jln jatibaru polisi tdk bs allcaps gertak...
# 1  sesama cewe lho kayaknya harusnya bisa lebih r...
# 2  kepingin gudeg mbarek bu hj amad foto dari goo...
# 3  jln jatibaru bagian dari wilayah tn abang peng...
# 4  sharing pengalaman aja kemarin jam number bata...
#
#                                               tokens  \
# 0  [soal, jln, jatibaru, polisi, tdk, bs, allcaps...
# 1  [sesama, cewe, lho, kayaknya, harusnya, bisa, ...
# 2  [kepingin, gudeg, mbarek, bu, hj, amad, foto, ...
# 3  [jln, jatibaru, bagian, dari, wilayah, tn, aba...
# 4  [sharing, pengalaman, aja, kemarin, jam, numbe...
#
#                                     tokens_perbaikan
# 0  [soal, jln, jatibaru, polisi, tidak, bs, allca...
# 1  [sesama, cewe, lho, kayaknya, harusnya, bisa, ...
# 2  [kepingin, gudeg, mbarek, bu, hj, amad, foto, ...
# 3  [jln, jatibaru, bagian, dari, wilayah, tn, aba...
# 4  [sharing, pengalaman, saja, kemarin, jam, numb...

# %%
df_new.iloc[0].tokens
# Out:
# ['soal',
#  'jln',
#  'jatibaru',
#  'polisi',
#  'tdk',
#  'bs',
#  'allcaps',
#  'gertak',
#  'allcaps',
#  'gubernur',
#  'emangny',
#  'polisi',
#  'tdk',
#  'ikut',
#  'pmbhasan',
#  'jgn',
#  'berpolitik',
#  'pengaturan',
#  'wilayah',
#  'hak',
#  'gubernur',
#  'persoalan',
#  'tn',
#  'abang',
#  'soal',
#  'turun',
#  'temurun',
#  'pelik',
#  'perlu',
#  'kesabaran',
#  'allcaps',
#  'username',
#  'allcaps',
#  'allcaps',
#  'username',
#  'allcaps',
#  'allcaps',
#  'url',
#  'allcaps']

# %%
df_new.iloc[0].tokens_perbaikan
# Out:
# ['soal',
#  'jln',
#  'jatibaru',
#  'polisi',
#  'tidak',
#  'bs',
#  'allcaps',
#  'gertak',
#  'allcaps',
#  'gubernur',
#  'emangny',
#  'polisi',
#  'tidak',
#  'ikut',
#  'pmbhasan',
#  'jgn',
#  'berpolitik',
#  'pengaturan',
#  'wilayah',
#  'hak',
#  'gubernur',
#  'persoalan',
#  'tn',
#  'abang',
#  'soal',
#  'turun',
#  'temurun',
#  'pelik',
#  'perlu',
#  'kesabaran',
#  'allcaps',
#  'username',
#  'allcaps',
#  'allcaps',
#  'username',
#  'allcaps',
#  'allcaps',
#  'url',
#  'allcaps']

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopword = nltk.corpus.stopwords.words('indonesian')

def remove_stopwords(text):
  text = [word for word in text if word not in stopword]
  return text

df_new['Stop_removal'] = df_new['tokens_perbaikan'].apply(lambda x: remove_stopwords(x))
df_new
# Out:
#                                                   tweet  \
# 0     Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
# 1     Sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2     Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 3     Jln Jatibaru,bagian dari wilayah Tn Abang.Peng...
# 4     Sharing pengalaman aja, kemarin jam 18.00 bata...
# ...                                                 ...
# 4396  Tahukah kamu, bahwa saat itu papa memejamkan m...
# 4397  Sulitnya menetapkan Calon Wapresnya Jokowi di ...
# 4398  5. masa depannya nggak jelas. lha iya, gimana ...
# 4399  [USERNAME] dulu beneran ada mahasiswa Teknik U...
# 4400  Ya Allah, hanya Engkau yang mengetahui rasa sa...
#
#                                                  step01  \
# 0     soal jln jatibaru polisi tdk bs allcaps gertak...
# 1     sesama cewe lho kayaknya harusnya bisa lebih r...
# 2     kepingin gudeg mbarek bu hj amad foto dari goo...
# 3     jln jatibaru bagian dari wilayah tn abang peng...
# 4     sharing pengalaman aja kemarin jam number bata...
# ...                                                 ...
# 4396  tahukah kamu bahwa saat itu papa memejamkan ma...
# 4397  sulitnya menetapkan calon wapresnya jokowi di ...
# 4398  number masa depannya nggak jelas lha iya giman...
# 4399  allcaps username allcaps dulu beneran ada maha...
# 4400  ya allah hanya engkau yang mengetahui rasa sak...
#
#                                                  tokens  \
# 0     [soal, jln, jatibaru, polisi, tdk, bs, allcaps...
# 1     [sesama, cewe, lho, kayaknya, harusnya, bisa, ...
# 2     [kepingin, gudeg, mbarek, bu, hj, amad, foto, ...
# 3     [jln, jatibaru, bagian, dari, wilayah, tn, aba...
# 4     [sharing, pengalaman, aja, kemarin, jam, numbe...
# ...                                                 ...
# 4396  [tahukah, kamu, bahwa, saat, itu, papa, memeja...
# 4397  [sulitnya, menetapkan, calon, wapresnya, jokow...
# 4398  [number, masa, depannya, nggak, jelas, lha, iy...
# 4399  [allcaps, username, allcaps, dulu, beneran, ad...
# 4400  [ya, allah, hanya, engkau, yang, mengetahui, r...
#
#                                        tokens_perbaikan  \
# 0     [soal, jln, jatibaru, polisi, tidak, bs, allca...
# 1     [sesama, cewe, lho, kayaknya, harusnya, bisa, ...
# 2     [kepingin, gudeg, mbarek, bu, hj, amad, foto, ...
# 3     [jln, jatibaru, bagian, dari, wilayah, tn, aba...
# 4     [sharing, pengalaman, saja, kemarin, jam, numb...
# ...                                                 ...
# 4396  [tahukah, kamu, bahwa, saat, itu, papa, memeja...
# 4397  [sulitnya, menetapkan, calon, wapresnya, jokow...
# 4398  [number, masa, depannya, tidak, jelas, lha, iy...
# 4399  [allcaps, username, allcaps, dulu, beneran, ad...
# 4400  [ya, allah, hanya, engkau, yang, mengetahui, r...
#
#                                            Stop_removal
# 0     [jln, jatibaru, polisi, bs, allcaps, gertak, a...
# 1     [cewe, lho, kayaknya, rasain, sibuk, jaga, ras...
# 2     [kepingin, gudeg, mbarek, bu, hj, amad, foto, ...
# 3     [jln, jatibaru, wilayah, tn, abang, pengaturan...
# 4     [sharing, pengalaman, kemarin, jam, number, ba...
# ...                                                 ...
# 4396  [tahukah, papa, memejamkan, matanya, menahan, ...
# 4397  [sulitnya, menetapkan, calon, wapresnya, jokow...
# 4398  [number, depannya, lha, iya, gimana, coba, lul...
# 4399  [allcaps, username, allcaps, beneran, mahasisw...
# 4400  [ya, allah, engkau, sakit, hati, sembuhkanlah,...
#
# [4401 rows x 5 columns]

# %%
df_new.iloc[0].tokens_perbaikan
# Out:
# ['soal',
#  'jln',
#  'jatibaru',
#  'polisi',
#  'tidak',
#  'bs',
#  'allcaps',
#  'gertak',
#  'allcaps',
#  'gubernur',
#  'emangny',
#  'polisi',
#  'tidak',
#  'ikut',
#  'pmbhasan',
#  'jgn',
#  'berpolitik',
#  'pengaturan',
#  'wilayah',
#  'hak',
#  'gubernur',
#  'persoalan',
#  'tn',
#  'abang',
#  'soal',
#  'turun',
#  'temurun',
#  'pelik',
#  'perlu',
#  'kesabaran',
#  'allcaps',
#  'username',
#  'allcaps',
#  'allcaps',
#  'username',
#  'allcaps',
#  'allcaps',
#  'url',
#  'allcaps']

# %%
df_new.iloc[0].Stop_removal
# Out:
# ['jln',
#  'jatibaru',
#  'polisi',
#  'bs',
#  'allcaps',
#  'gertak',
#  'allcaps',
#  'gubernur',
#  'emangny',
#  'polisi',
#  'pmbhasan',
#  'jgn',
#  'berpolitik',
#  'pengaturan',
#  'wilayah',
#  'hak',
#  'gubernur',
#  'tn',
#  'abang',
#  'turun',
#  'temurun',
#  'pelik',
#  'kesabaran',
#  'allcaps',
#  'username',
#  'allcaps',
#  'allcaps',
#  'username',
#  'allcaps',
#  'allcaps',
#  'url',
#  'allcaps']

# %%
i=0
final_string_tokens = []
for text in df_new['Stop_removal'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step02"] = final_string_tokens

# %%
df_new.head()
# Out:
#                                                tweet  \
# 0  Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
# 1  Sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2  Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 3  Jln Jatibaru,bagian dari wilayah Tn Abang.Peng...
# 4  Sharing pengalaman aja, kemarin jam 18.00 bata...
#
#                                               step01  \
# 0  soal jln jatibaru polisi tdk bs allcaps gertak...
# 1  sesama cewe lho kayaknya harusnya bisa lebih r...
# 2  kepingin gudeg mbarek bu hj amad foto dari goo...
# 3  jln jatibaru bagian dari wilayah tn abang peng...
# 4  sharing pengalaman aja kemarin jam number bata...
#
#                                               tokens  \
# 0  [soal, jln, jatibaru, polisi, tdk, bs, allcaps...
# 1  [sesama, cewe, lho, kayaknya, harusnya, bisa, ...
# 2  [kepingin, gudeg, mbarek, bu, hj, amad, foto, ...
# 3  [jln, jatibaru, bagian, dari, wilayah, tn, aba...
# 4  [sharing, pengalaman, aja, kemarin, jam, numbe...
#
#                                     tokens_perbaikan  \
# 0  [soal, jln, jatibaru, polisi, tidak, bs, allca...
# 1  [sesama, cewe, lho, kayaknya, harusnya, bisa, ...
# 2  [kepingin, gudeg, mbarek, bu, hj, amad, foto, ...
# 3  [jln, jatibaru, bagian, dari, wilayah, tn, aba...
# 4  [sharing, pengalaman, saja, kemarin, jam, numb...
#
#                                         Stop_removal  \
# 0  [jln, jatibaru, polisi, bs, allcaps, gertak, a...
# 1  [cewe, lho, kayaknya, rasain, sibuk, jaga, ras...
# 2  [kepingin, gudeg, mbarek, bu, hj, amad, foto, ...
# 3  [jln, jatibaru, wilayah, tn, abang, pengaturan...
# 4  [sharing, pengalaman, kemarin, jam, number, ba...
#
#                                               step02
# 0  jln jatibaru polisi bs allcaps gertak allcaps ...
# 1  cewe lho kayaknya rasain sibuk jaga rasain sak...
# 2  kepingin gudeg mbarek bu hj amad foto google s...
# 3  jln jatibaru wilayah tn abang pengaturan wilay...
# 4  sharing pengalaman kemarin jam number batalin ...

# %%
# !pip install sastrawi

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
for sentence in df_new["step02"].astype(str).head(10).values:
    print(stemmer.stem(sentence))
# Out:
# jln jatibaru polisi bs allcaps gertak allcaps gubernur emangny polisi pmbhasan jgn politik atur wilayah hak gubernur tn abang turun turun pelik sabar allcaps username allcaps allcaps username allcaps allcaps url allcaps
# cewe lho kayak rasain sibuk jaga rasain sakit haid panik pulang malem gimana orang asing wajar korban takut curhat bela hujat
# kepingin gudeg mbarek bu hj amad foto google sengaja biar teman teman jg bayang bagi indah
# jln jatibaru wilayah tn abang atur wilayah tgg jwb wwnang gub tng abng rumit gub2 trdahulu skrg sedng benah agr bermnfaat mohon otak pikir wajar kecuali otak butek ya allcaps url allcaps
# sharing alam kemarin jam number batalin tiket stasiun pasar senen lancar antri rame number menit beress coba twips jam jam segitu cc allcaps username allcaps
# sekian thread baca thread aneh sih tulis sumpah aneh banget ngatain lebay bikin thread hadeh jago nulis tulis beranta thread mbak
# sharing temen tuh emg banget saat lu ngerasa lu berat banget temen berat ngga apa2nya banding
# orang pake ponco jas hujan pake kasur ya gara2 saking gak apa2 mamak bilang tuh pernik gak ngalamin madu kayak skrg2 org tidur nya pake ponco gimane madu
# contoh gemar sudut teriak toleran tp gemar tuduh gemar men judge dasar versi tau
# pulang udah number lebaran dilema apa2 rumah lebaran buka puasa bareng cuman number keluarga sahur

# %%
df_new.head(10)
# Out:
#                                                tweet  \
# 0  Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
# 1  Sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2  Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 3  Jln Jatibaru,bagian dari wilayah Tn Abang.Peng...
# 4  Sharing pengalaman aja, kemarin jam 18.00 bata...
# 5  Dari sekian banyak thread yang aku baca, threa...
# 6  Sharing sama temen tuh emg guna bgt. Disaat lu...
# 7  Orang lain kalau pake ponco itu buat jas hujan...
# 8  Contoh mereka yg gemar menyudutkan, teriak pal...
# 9  Pulang udah H-4 lebaran dilema sekali. Seperti...
#
#                                               step01  \
# 0  soal jln jatibaru polisi tdk bs allcaps gertak...
# 1  sesama cewe lho kayaknya harusnya bisa lebih r...
# 2  kepingin gudeg mbarek bu hj amad foto dari goo...
# 3  jln jatibaru bagian dari wilayah tn abang peng...
# 4  sharing pengalaman aja kemarin jam number bata...
# 5  dari sekian banyak thread yang aku baca thread...
# 6  sharing sama temen tuh emg guna bgt disaat lu ...
# 7  orang lain kalau pake ponco itu buat jas hujan...
# 8  contoh mereka yg gemar menyudutkan teriak pali...
# 9  pulang udah number lebaran dilema sekali seper...
#
#                                               tokens  \
# 0  [soal, jln, jatibaru, polisi, tdk, bs, allcaps...
# 1  [sesama, cewe, lho, kayaknya, harusnya, bisa, ...
# 2  [kepingin, gudeg, mbarek, bu, hj, amad, foto, ...
# 3  [jln, jatibaru, bagian, dari, wilayah, tn, aba...
# 4  [sharing, pengalaman, aja, kemarin, jam, numbe...
# 5  [dari, sekian, banyak, thread, yang, aku, baca...
# 6  [sharing, sama, temen, tuh, emg, guna, bgt, di...
# 7  [orang, lain, kalau, pake, ponco, itu, buat, j...
# 8  [contoh, mereka, yg, gemar, menyudutkan, teria...
# 9  [pulang, udah, number, lebaran, dilema, sekali...
#
#                                     tokens_perbaikan  \
# 0  [soal, jln, jatibaru, polisi, tidak, bs, allca...
# 1  [sesama, cewe, lho, kayaknya, harusnya, bisa, ...
# 2  [kepingin, gudeg, mbarek, bu, hj, amad, foto, ...
# 3  [jln, jatibaru, bagian, dari, wilayah, tn, aba...
# 4  [sharing, pengalaman, saja, kemarin, jam, numb...
# 5  [dari, sekian, banyak, thread, yang, aku, baca...
# 6  [sharing, sama, temen, tuh, emg, guna, banget,...
# 7  [orang, lain, kalau, pake, ponco, itu, buat, j...
# 8  [contoh, mereka, yang, gemar, menyudutkan, ter...
# 9  [pulang, udah, number, lebaran, dilema, sekali...
#
#                                         Stop_removal  \
# 0  [jln, jatibaru, polisi, bs, allcaps, gertak, a...
# 1  [cewe, lho, kayaknya, rasain, sibuk, jaga, ras...
# 2  [kepingin, gudeg, mbarek, bu, hj, amad, foto, ...
# 3  [jln, jatibaru, wilayah, tn, abang, pengaturan...
# 4  [sharing, pengalaman, kemarin, jam, number, ba...
# 5  [sekian, thread, baca, thread, aneh, sih, penu...
# 6  [sharing, temen, tuh, emg, banget, disaat, lu,...
# 7  [orang, pake, ponco, jas, hujan, pake, kasur, ...
# 8  [contoh, gemar, menyudutkan, teriak, toleran, ...
# 9  [pulang, udah, number, lebaran, dilema, apa2, ...
#
#                                               step02
# 0  jln jatibaru polisi bs allcaps gertak allcaps ...
# 1  cewe lho kayaknya rasain sibuk jaga rasain sak...
# 2  kepingin gudeg mbarek bu hj amad foto google s...
# 3  jln jatibaru wilayah tn abang pengaturan wilay...
# 4  sharing pengalaman kemarin jam number batalin ...
# 5  sekian thread baca thread aneh sih penulisan s...
# 6  sharing temen tuh emg banget disaat lu ngerasa...
# 7  orang pake ponco jas hujan pake kasur ya gara2...
# 8  contoh gemar menyudutkan teriak toleran tp gem...
# 9  pulang udah number lebaran dilema apa2 dirumah...

# %% [markdown]
# ## simpan hasil preprocessing

# %%
df_new.to_csv('clean_dataset_part01.csv',sep=";")

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('clean_dataset_part01.csv',sep=";")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4401 entries, 0 to 4400
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        4401 non-null   int64
#  1   tweet             4401 non-null   object
#  2   step01            4401 non-null   object
#  3   tokens            4401 non-null   object
#  4   tokens_perbaikan  4401 non-null   object
#  5   Stop_removal      4401 non-null   object
#  6   step02            4401 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 240.8+ KB

# %%
print(dataset.columns)
# Out:
# Index(['Unnamed: 0', 'tweet', 'step01', 'tokens', 'tokens_perbaikan',
#        'Stop_removal', 'step02'],
#       dtype='object')

# %%
dataset_feature = dataset['step02'].astype(str)

# %%
dataset_feature.head(10)
# Out:
# 0    jln jatibaru polisi bs allcaps gertak allcaps ...
# 1    cewe lho kayaknya rasain sibuk jaga rasain sak...
# 2    kepingin gudeg mbarek bu hj amad foto google s...
# 3    jln jatibaru wilayah tn abang pengaturan wilay...
# 4    sharing pengalaman kemarin jam number batalin ...
# 5    sekian thread baca thread aneh sih penulisan s...
# 6    sharing temen tuh emg banget disaat lu ngerasa...
# 7    orang pake ponco jas hujan pake kasur ya gara2...
# 8    contoh gemar menyudutkan teriak toleran tp gem...
# 9    pulang udah number lebaran dilema apa2 dirumah...
# Name: step02, dtype: object

# %%
dataset_label = dataset['tweet']

# %%
dataset_label.head(10)
# Out:
# 0    Soal jln Jatibaru,polisi tdk bs GERTAK gubernu...
# 1    Sesama cewe lho (kayaknya), harusnya bisa lebi...
# 2    Kepingin gudeg mbarek Bu hj. Amad Foto dari go...
# 3    Jln Jatibaru,bagian dari wilayah Tn Abang.Peng...
# 4    Sharing pengalaman aja, kemarin jam 18.00 bata...
# 5    Dari sekian banyak thread yang aku baca, threa...
# 6    Sharing sama temen tuh emg guna bgt. Disaat lu...
# 7    Orang lain kalau pake ponco itu buat jas hujan...
# 8    Contoh mereka yg gemar menyudutkan, teriak pal...
# 9    Pulang udah H-4 lebaran dilema sekali. Seperti...
# Name: tweet, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset['text_length'] = dataset['step02'].astype(str).apply(len)

plt.figure(figsize=(12,8))
sns.histplot(dataset['text_length'], kde=True)
plt.title("Distribusi Panjang Teks")
plt.show()

# %%
dataset_label.value_counts()
# Out:
# tweet
# [USERNAME] Selamat Siang Sahabat Pos. Kiriman tsb sudah diterima ya sahabat. Terima kasih telah mempercayakan dan menggunakan layanan kami :) ^FD [URL]                                                                                                                                            4
# All We Know of Heaven, All We Need of Hell - PVRIS (2017) Gue ngikutin PVRIS dari awal, gue rasa album yg skrg lagu2nya lebih mature, sangar, dark, tp fragile. Konsep keseluruhan album + mv + dll nya keren parah. W suka lagu Mercy, Anyone Else, sama Winter [URL]                             2
# belajar agama yg tuntas jd nga ngarang dalam hidup. Isa saja disebut2 dialquran trus lu mau jelek2in Isa?? Bisa baca alquran ga? [URL]                                                                                                                                                             2
# Aku gak salah bila mohon pd [USERNAME], segera Perintahkan MENKES utk menambah Ruangan Khusus "Sakit Jiwa" pd stiap Rmh Sakit. Sbab, tdk menutup kemungkinan, USAI PILPRES, stiap Rmh Sakit akan dibanjiri Pasien "Sakit Jiwa". Tanda2 kearah sana itu sdh ada. Saat ini banyak yg STRESS [URL]    2
# [USERNAME] [USERNAME] Tidak disemua tempat kita boleh melaksanakan sholat, salah satunya di bangunan yang didirikan untuk kekafiran (salah satunya gereja). Aku berlindung kepada ALLAAH SWT. dari godaan setan yang terkutuk. [URL]                                                               2
#                                                                                                                                                                                                                                                                                                   ..
# Tahukah kamu, bahwa saat itu papa memejamkan matanya dan menahan gejolak dan batinnya. Bahwa papa sangat ingin mengikuti keinginanmu tapu lagi-lagi dia HARUS menjagamu?                                                                                                                           1
# Sulitnya menetapkan Calon Wapresnya Jokowi di Pilpres 2019 salah satunya disebabkan gemuknya partai koalisi yang mengusung petahana. Sehingga sikap kehati-hatian agar tidak ada yang terluka dari partai pengusung harus tetap dijaga #Pilpres2019 #Pilpres #Jokowi #Parpol                       1
# 5. masa depannya nggak jelas. lha iya, gimana mau jelas coba? lulusan seni, bisanya cuma nari, mau kerja apa? nari-nari doang. berapa sih, penghasilannya penari? kerja juga gak tetap~ #dontdateadancer                                                                                           1
# [USERNAME] dulu beneran ada mahasiswa Teknik UI nembak pacarnya pas sahur di Kukusan Teknik Depok, diliput kru Katakan Cinta (dan belum pacaran mereka). Sekarang udah nikah dan punya anak. Pernah diceritain laman UI Shitposting/Divarposting juga.                                             1
# segitu hepi nyaa yah bs ketemu pacarnyanyi2 an gajelas di mobil trs gandengan tangan, duh gt aja udh hepi mah aku ngga kerasa udh 4.5 taun aja                                                                                                                                                     1
# Name: count, Length: 4389, dtype: int64

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.model_selection import train_test_split

# %%
train_x, test_x, train_label, test_label = train_test_split(dataset_feature, dataset_label, test_size = 0.3, random_state=42)

# %%
test_x
# Out:
# 274     ya repeated allah repeated smoga number number...
# 3431    allcaps belajarlah orangtuamu allcaps repeated...
# 4021    hallo allcaps username allcaps mohon dibantu y...
# 1027    gak sih situ mikir kalo ngerjain tugas gausah ...
# 1589    selamat pagi warga gunungkidul suasana pagi ka...
#                               ...
# 3821    allcaps username allcaps namanya kerja _ profe...
# 1551    habis kegiatan yah hati dijalannya yah iya uda...
# 549     allcaps username allcaps allcaps username allc...
# 557     abis makan bumen makan sosis aliando blg udah ...
# 1829    gegara td malem treak treak gemash ngliat indo...
# Name: step02, Length: 1321, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
Tfidf_Vectorizer = TfidfVectorizer()

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
from sklearn.pipeline import Pipeline
classifier_nb = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('model', MultinomialNB()),
])

# %%
parameters_nb = {
    'tfidf__ngram_range': [(1, 1), (1, 2), (1, 3), (1, 4)],
    'model__alpha': (0.0001, 0.001, 0.1, 1, 10, 100)
}

# %%
classifier_nb = GridSearchCV(classifier_nb, parameters_nb, cv = 3, n_jobs=-1)

# %%
classifier_nb.fit(train_x, train_label.ravel())
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_6452\4039834798.py:1: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   classifier_nb.fit(train_x, train_label.ravel())
# e:\STKI\env\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(
# e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py:490: FitFailedWarning:
# 66 fits failed out of a total of 72.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 794, in fit
#     self._count(X, Y)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 922, in _count
#     self.feature_count_ += safe_sparse_dot(Y.T, X)
#                            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\utils\extmath.py", line 227, in safe_sparse_dot
#     ret = a @ b
#           ~~^~~
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 914, in __rmatmul__
#     return self._rmatmul_dispatch(other)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 895, in _rmatmul_dispatch
#     ret = self.transpose()._matmul_dispatch(tr)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 800, in _matmul_dispatch
#     return self._matmul_multivector(other)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_compressed.py", line 408, in _matmul_multivector
#     fn(M, N, n_vecs, self.indptr, self.indices, self.data,
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 32.1 MiB for an array with shape (4204544,) and data type float64
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 796, in fit
#     self._update_feature_log_prob(alpha)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 930, in _update_feature_log_prob
#     self.feature_log_prob_ = np.log(smoothed_fc) - np.log(
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 175. MiB for an array with shape (2052, 11172) and data type float64
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 794, in fit
#     self._count(X, Y)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 922, in _count
#     self.feature_count_ += safe_sparse_dot(Y.T, X)
#                            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\utils\extmath.py", line 227, in safe_sparse_dot
#     ret = a @ b
#           ~~^~~
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 914, in __rmatmul__
#     return self._rmatmul_dispatch(other)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 895, in _rmatmul_dispatch
#     ret = self.transpose()._matmul_dispatch(tr)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 800, in _matmul_dispatch
#     return self._matmul_multivector(other)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_compressed.py", line 403, in _matmul_multivector
#     result = np.zeros((M, n_vecs),
#              ^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 700. MiB for an array with shape (44761, 2049) and data type float64
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 793, in fit
#     self._init_counters(n_classes, n_features)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 802, in _init_counters
#     self.feature_count_ = np.zeros((n_classes, n_features), dtype=np.float64)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 695. MiB for an array with shape (2048, 44475) and data type float64
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 793, in fit
#     self._init_counters(n_classes, n_features)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 802, in _init_counters
#     self.feature_count_ = np.zeros((n_classes, n_features), dtype=np.float64)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 694. MiB for an array with shape (2052, 44303) and data type float64
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 793, in fit
#     self._init_counters(n_classes, n_features)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 802, in _init_counters
#     self.feature_count_ = np.zeros((n_classes, n_features), dtype=np.float64)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 1.22 GiB for an array with shape (2049, 80159) and data type float64
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 793, in fit
#     self._init_counters(n_classes, n_features)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 802, in _init_counters
#     self.feature_count_ = np.zeros((n_classes, n_features), dtype=np.float64)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 1.22 GiB for an array with shape (2048, 79645) and data type float64
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 793, in fit
#     self._init_counters(n_classes, n_features)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 802, in _init_counters
#     self.feature_count_ = np.zeros((n_classes, n_features), dtype=np.float64)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 1.22 GiB for an array with shape (2052, 79504) and data type float64
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 771, in fit
#     Y = labelbin.fit_transform(y)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\preprocessing\_label.py", line 354, in fit_transform
#     return self.fit(y).transform(y)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\preprocessing\_label.py", line 391, in transform
#     return label_binarize(
#            ^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\utils\_param_validation.py", line 191, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\preprocessing\_label.py", line 647, in label_binarize
#     Y = xp.asarray(Y.toarray(), device=device_)
#                    ^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_compressed.py", line 996, in toarray
#     out = self._process_toarray_args(order, out)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 1530, in _process_toarray_args
#     return np.zeros(self.shape, dtype=self.dtype, order=order)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 32.1 MiB for an array with shape (2053, 2049) and data type int64
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 793, in fit
#     self._init_counters(n_classes, n_features)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 802, in _init_counters
#     self.feature_count_ = np.zeros((n_classes, n_features), dtype=np.float64)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 1.74 GiB for an array with shape (2048, 113916) and data type float64
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 793, in fit
#     self._init_counters(n_classes, n_features)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 802, in _init_counters
#     self.feature_count_ = np.zeros((n_classes, n_features), dtype=np.float64)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 1.74 GiB for an array with shape (2052, 113851) and data type float64
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 796, in fit
#     self._update_feature_log_prob(alpha)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 927, in _update_feature_log_prob
#     smoothed_fc = self.feature_count_ + alpha
#                   ~~~~~~~~~~~~~~~~~~~~^~~~~~~
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 175. MiB for an array with shape (2052, 11172) and data type float64
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 793, in fit
#     self._init_counters(n_classes, n_features)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 802, in _init_counters
#     self.feature_count_ = np.zeros((n_classes, n_features), dtype=np.float64)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 700. MiB for an array with shape (2049, 44761) and data type float64
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 796, in fit
#     self._update_feature_log_prob(alpha)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 930, in _update_feature_log_prob
#     self.feature_log_prob_ = np.log(smoothed_fc) - np.log(
#                              ^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 695. MiB for an array with shape (2048, 44475) and data type float64
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 793, in fit
#     self._init_counters(n_classes, n_features)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 802, in _init_counters
#     self.feature_count_ = np.zeros((n_classes, n_features), dtype=np.float64)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 1.75 GiB for an array with shape (2049, 114687) and data type float64
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 794, in fit
#     self._count(X, Y)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 922, in _count
#     self.feature_count_ += safe_sparse_dot(Y.T, X)
#                            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\utils\extmath.py", line 227, in safe_sparse_dot
#     ret = a @ b
#           ~~^~~
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 914, in __rmatmul__
#     return self._rmatmul_dispatch(other)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 895, in _rmatmul_dispatch
#     ret = self.transpose()._matmul_dispatch(tr)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 800, in _matmul_dispatch
#     return self._matmul_multivector(other)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_compressed.py", line 403, in _matmul_multivector
#     result = np.zeros((M, n_vecs),
#              ^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 176. MiB for an array with shape (11283, 2049) and data type float64
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 794, in fit
#     self._count(X, Y)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 922, in _count
#     self.feature_count_ += safe_sparse_dot(Y.T, X)
#                            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\utils\extmath.py", line 227, in safe_sparse_dot
#     ret = a @ b
#           ~~^~~
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 914, in __rmatmul__
#     return self._rmatmul_dispatch(other)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 895, in _rmatmul_dispatch
#     ret = self.transpose()._matmul_dispatch(tr)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 800, in _matmul_dispatch
#     return self._matmul_multivector(other)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_compressed.py", line 408, in _matmul_multivector
#     fn(M, N, n_vecs, self.indptr, self.indices, self.data,
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 32.1 MiB for an array with shape (4206597,) and data type float64
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 793, in fit
#     self._init_counters(n_classes, n_features)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 802, in _init_counters
#     self.feature_count_ = np.zeros((n_classes, n_features), dtype=np.float64)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 175. MiB for an array with shape (2048, 11192) and data type float64
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 794, in fit
#     self._count(X, Y)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 922, in _count
#     self.feature_count_ += safe_sparse_dot(Y.T, X)
#                            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\utils\extmath.py", line 227, in safe_sparse_dot
#     ret = a @ b
#           ~~^~~
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 914, in __rmatmul__
#     return self._rmatmul_dispatch(other)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 895, in _rmatmul_dispatch
#     ret = self.transpose()._matmul_dispatch(tr)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 800, in _matmul_dispatch
#     return self._matmul_multivector(other)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_compressed.py", line 408, in _matmul_multivector
#     fn(M, N, n_vecs, self.indptr, self.indices, self.data,
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 32.2 MiB for an array with shape (4214808,) and data type float64
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 794, in fit
#     self._count(X, Y)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 922, in _count
#     self.feature_count_ += safe_sparse_dot(Y.T, X)
#                            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\utils\extmath.py", line 227, in safe_sparse_dot
#     ret = a @ b
#           ~~^~~
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 914, in __rmatmul__
#     return self._rmatmul_dispatch(other)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 895, in _rmatmul_dispatch
#     ret = self.transpose()._matmul_dispatch(tr)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 800, in _matmul_dispatch
#     return self._matmul_multivector(other)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_compressed.py", line 403, in _matmul_multivector
#     result = np.zeros((M, n_vecs),
#              ^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 695. MiB for an array with shape (44475, 2048) and data type float64
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 794, in fit
#     self._count(X, Y)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 922, in _count
#     self.feature_count_ += safe_sparse_dot(Y.T, X)
#                            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\utils\extmath.py", line 227, in safe_sparse_dot
#     ret = a @ b
#           ~~^~~
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 914, in __rmatmul__
#     return self._rmatmul_dispatch(other)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 895, in _rmatmul_dispatch
#     ret = self.transpose()._matmul_dispatch(tr)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_base.py", line 800, in _matmul_dispatch
#     return self._matmul_multivector(other)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\scipy\sparse\_compressed.py", line 403, in _matmul_multivector
#     result = np.zeros((M, n_vecs),
#              ^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 694. MiB for an array with shape (44303, 2052) and data type float64
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 796, in fit
#     self._update_feature_log_prob(alpha)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 930, in _update_feature_log_prob
#     self.feature_log_prob_ = np.log(smoothed_fc) - np.log(
#                              ^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 175. MiB for an array with shape (2048, 11192) and data type float64
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 796, in fit
#     self._update_feature_log_prob(alpha)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 930, in _update_feature_log_prob
#     self.feature_log_prob_ = np.log(smoothed_fc) - np.log(
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 700. MiB for an array with shape (2049, 44761) and data type float64
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 793, in fit
#     self._init_counters(n_classes, n_features)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 802, in _init_counters
#     self.feature_count_ = np.zeros((n_classes, n_features), dtype=np.float64)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 176. MiB for an array with shape (2049, 11283) and data type float64
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\STKI\env\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\pipeline.py", line 621, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#   File "e:\STKI\env\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 793, in fit
#     self._init_counters(n_classes, n_features)
#   File "e:\STKI\env\Lib\site-packages\sklearn\naive_bayes.py", line 802, in _init_counters
#     self.feature_count_ = np.zeros((n_classes, n_features), dtype=np.float64)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 175. MiB for an array with shape (2052, 11172) and data type float64
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# e:\STKI\env\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan]
#   warnings.warn(
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                        ('model', MultinomialNB())]),
#              n_jobs=-1,
#              param_grid={'model__alpha': (0.0001, 0.001, 0.1, 1, 10, 100),
#                          'tfidf__ngram_range': [(1, 1), (1, 2), (1, 3),
#                                                 (1, 4)]})

# %%
y_pred_nb_train = classifier_nb.predict(train_x)
accuracy_nb_train = accuracy_score(train_label, y_pred_nb_train)
print("Accuracy Training set: ", accuracy_nb_train)

y_pred_nb_test = classifier_nb.predict(test_x)
accuracy_nb_test = accuracy_score(test_label, y_pred_nb_test)
print("Accuracy Test set: ", accuracy_nb_test)
# Out:
# Accuracy Training set:  0.999025974025974
# Accuracy Test set:  0.001514004542013626

# %%
recall_nb_train = recall_score(train_label, y_pred_nb_train, average='weighted')
print("Recall Training set: ", recall_nb_train)

recall_nb_test = recall_score(test_label, y_pred_nb_test, average='weighted')
print("Recall Test set: ", recall_nb_test)
# Out:
# Recall Training set:  0.999025974025974
# Recall Test set:  0.001514004542013626
# e:\STKI\env\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
precision_nb_train = precision_score(train_label, y_pred_nb_train, average='weighted')
print("Precision Training set: ", precision_nb_train)

precision_nb_test = precision_score(test_label, y_pred_nb_test, average='weighted')
print("Precision Test set: ", precision_nb_test)
# Out:
# Precision Training set:  0.998538961038961
# Precision Test set:  0.000757002271006813
# e:\STKI\env\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# e:\STKI\env\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
f1_nb_train = f1_score(train_label, y_pred_nb_train, average='weighted')
print("F1 Training set: ", f1_nb_train)

f1_nb_test = f1_score(test_label, y_pred_nb_test, average='weighted')
print("F1 Test set: ", f1_nb_test)
# Out:
# F1 Training set:  0.9987012987012988
# F1 Test set:  0.0010093363613424174

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

# pastikan label & prediksi bentuknya 1D dan sejenis
y_true = test_label
y_pred = y_pred_nb_test

# cek jumlah kelas (opsional tapi disarankan)
print("Jumlah kelas:", len(np.unique(y_true)))

# hitung confusion matrix
cm = confusion_matrix(y_true, y_pred)

# plot
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='viridis')
plt.xlabel("Predicted values", fontsize=12)
plt.ylabel("Actual values", fontsize=12)
plt.title("Confusion Matrix", fontsize=14)
plt.show()
# Out:
# Jumlah kelas: 1320

# %%
classifier_nb.best_estimator_
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('model', MultinomialNB(alpha=0.1))])

# %%
for param_name in sorted(parameters_nb.keys()):
    print("%s: %r" % (param_name, classifier_nb.best_params_[param_name]))
# Out:
# model__alpha: 0.1
# tfidf__ngram_range: (1, 1)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
train_x.dtype
# Out:
# dtype('O')

# %%
test_x_encoded = label_encoder.fit_transform(test_x)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
train_x_encoded = label_encoder.fit_transform(train_x)

# %%
train_x_encoded.dtype
# Out:
# dtype('int64')

# %%
train_x_encoded = train_x_encoded.reshape(-1, 1)
# train_label = train_label.reshape(-1, 1)

# %%
test_x_encoded = test_x_encoded.reshape(-1, 1)

# %%
model = KNeighborsClassifier(n_neighbors=3)
model.fit(train_x_encoded, train_label)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred_knn_train = model.predict(train_x_encoded)
accuracy_knn_train = accuracy_score(train_label, y_pred_knn_train)
print("Accuracy Training set: ", accuracy_knn_train)

y_pred_knn_test = model.predict(test_x_encoded)
accuracy_knn_test = accuracy_score(test_label, y_pred_knn_test)
print("Accuracy Test set: ", accuracy_knn_test)
# Out:
# Accuracy Training set:  0.6819620253164557
# Accuracy Test set:  0.36162361623616235

# %%
recall_knn_train = recall_score(train_label, y_pred_knn_train, average='weighted')
print("Recall Training set: ", recall_knn_train)

recall_knn_test = recall_score(test_label, y_pred_knn_test, average='weighted')
print("Recall Test set: ", recall_knn_test)
# Out:
# Recall Training set:  0.6819620253164557
# Recall Test set:  0.36162361623616235

# %%
precision_knn_train = precision_score(train_label, y_pred_knn_train, average='weighted')
print("Precision Training set: ", precision_knn_train)

precision_knn_test = precision_score(test_label, y_pred_knn_test, average='weighted')
print("Precision Test set: ", precision_knn_test)
# Out:
# Precision Training set:  0.7011272070435527
# Precision Test set:  0.39319546180536435

# %%
f1_knn_train = f1_score(train_label, y_pred_knn_train, average='weighted')
print("F1 Training set: ", f1_knn_train)

f1_knn_test = f1_score(test_label, y_pred_knn_test, average='weighted')
print("F1 Test set: ", f1_knn_test)
# Out:
# F1 Training set:  0.6865068520468985
# F1 Test set:  0.3717346622765151

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(test_label, y_pred_knn_test), annot=True, cmap = 'viridis', fmt='.0f')
plt.xlabel("Predicted values", fontdict = {'size':14}, labelpad = 10)
plt.ylabel("Actual values"   , fontdict = {'size':14}, labelpad = 10)
plt.title ("Confusion Matrix", fontdict = {'size':18}, pad = 20)
plt.show()

# %%
models = [        
          ('Naive Bayes Multinomial', accuracy_nb_train, accuracy_nb_test),
          ('KNN', accuracy_knn_train, accuracy_knn_test),
         ]

# %%
predict = pd.DataFrame(data = models, columns=['Model', 'Training Accuracy', 'Test Accuracy'])
predict
# Out:
#                      Model  Training Accuracy  Test Accuracy
# 0  Naive Bayes Multinomial           0.976266       0.590406
# 1                      KNN           0.681962       0.361624

# %%
models_comparison = [                        
                        ('Naive Bayes Multinomial', accuracy_nb_test, recall_nb_test, precision_nb_test, f1_nb_test),
                        ('KNN', accuracy_knn_test, recall_knn_test, precision_knn_test, f1_knn_test),                   
                    ]

# %%
comparison = pd.DataFrame(data = models_comparison, columns=['Model', 'Accuracy', 'Recall', 'Precision', 'F1 Weighted'])
comparison
# Out:
#                      Model  Accuracy    Recall  Precision  F1 Weighted
# 0  Naive Bayes Multinomial  0.590406  0.590406   0.569541     0.572316
# 1                      KNN  0.361624  0.361624   0.393195     0.371735

# %%
import numpy as np

f, axes = plt.subplots(2,1, figsize=(14,10))

predict.sort_values(by=['Training Accuracy'], ascending=False, inplace=True)

sns.barplot(x='Training Accuracy', y='Model', data = predict, palette='Blues_d', ax = axes[0])
#axes[0].set(xlabel='Region', ylabel='Charges')
axes[0].set_xlabel('Training Accuracy', size=16)
axes[0].set_ylabel('Model')
axes[0].set_xlim(0,1.0)
axes[0].set_xticks(np.arange(0, 1.1, 0.1))

predict.sort_values(by=['Test Accuracy'], ascending=False, inplace=True)

sns.barplot(x='Test Accuracy', y='Model', data = predict, palette='Greens_d', ax = axes[1])
#axes[0].set(xlabel='Region', ylabel='Charges')
axes[1].set_xlabel('Test Accuracy', size=16)
axes[1].set_ylabel('Model')
axes[1].set_xlim(0,1.0)
axes[1].set_xticks(np.arange(0, 1.1, 0.1))

plt.show()

# %%
import joblib

# %%
# save the model to disk
joblib.dump(classifier_nb.best_estimator_, 'classifier_nb.best_estimator_.sav', compress=1)
# Out:
# ['classifier_nb.best_estimator_.sav']
